# %%
# !pip install google-genai -q

# %%
import numpy as np
import matplotlib as plt

# %%
from google import genai
from google.genai import types

# %%
api_key = "Add your own api key"

# %%
client = genai.Client(api_key=api_key)

# %%
EMB_MODEL = "gemini-embedding-2"

# %%
def embed(text):
  result = client.models.embed_content(
      model = EMB_MODEL,
      contents=text,
      config=types.EmbedContentConfig(output_dimensionality=768                                )
  )
  return result.embeddings[0].values

# %%
vec = embed("machine learning")

print("Dimensions:", len(vec))
print("First 5:", [round(x,3) for x in vec[:5]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_361/790465675.py in <cell line: 0>()
# ----> 1 vec = embed("machine learning")
#       2
#       3 print("Dimensions:", len(vec))
#       4 print("First 5:", [round(x,3) for x in vec[:5]])
#
# /tmp/ipykernel_361/2018096770.py in embed(text)
#       1 def embed(text):
#       2   result = client.models.embed_content(
# ----> 3       model = EMB_MODEL,
#       4       contents=text,
#       5       config=types.EmbedContentConfig(output_dimensionality=768                                )
#
# NameError: name 'EMB_MODEL' is not defined
