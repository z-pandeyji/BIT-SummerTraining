# %%
# !pip install google-genai openai -q

# %%
from google import genai

# %%
from getpass import getpass

# %%
api_key = "Add your own api key"

# %%
client = genai.Client(api_key=api_key)

# %%
MODEL= "gemini-3.5-flash"

# %%
response = client.models.generate_content(
    model=MODEL,
    contents="Explain recusion to a 3rd year CS students in 2 lines, with one example"
)

# %%
print(response.text)
# Out:
# Recursion is the programmatic application of mathematical induction, where a function solves a complex problem by pushing smaller sub-problems onto the call stack until it hits a base case.
# Example: `int factorial(int n) { return (n <= 1) ? 1 : n * factorial(n - 1); }`
