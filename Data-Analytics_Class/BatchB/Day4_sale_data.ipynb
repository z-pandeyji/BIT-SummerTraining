# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rohitsahoo/sales-forecasting")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'sales-forecasting' dataset.
# Path to dataset files: /kaggle/input/sales-forecasting

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/sales-forecasting/train.csv")

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[["Order ID", "Order Date", "Category"]]
# Out:
#             Order ID  Order Date         Category
# 0     CA-2017-152156  08/11/2017        Furniture
# 1     CA-2017-152156  08/11/2017        Furniture
# 2     CA-2017-138688  12/06/2017  Office Supplies
# 3     US-2016-108966  11/10/2016        Furniture
# 4     US-2016-108966  11/10/2016  Office Supplies
# ...              ...         ...              ...
# 9795  CA-2017-125920  21/05/2017  Office Supplies
# 9796  CA-2016-128608  12/01/2016  Office Supplies
# 9797  CA-2016-128608  12/01/2016       Technology
# 9798  CA-2016-128608  12/01/2016       Technology
# 9799  CA-2016-128608  12/01/2016       Technology
#
# [9800 rows x 3 columns]

# %%
df[df["Category"] == "Furniture"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9786    9787  US-2015-114377  05/11/2015  05/11/2015        Same Day
# 9787    9788  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9788    9789  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9790    9791  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9792    9793  CA-2015-127166  21/05/2015  23/05/2015    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# ...

# %%
df[(df["Region"] == "West") & (df["Category"] == "Technology")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 19        20  CA-2015-143336  27/08/2015  01/09/2015    Second Class
# 26        27  CA-2017-121755  16/01/2017  20/01/2017    Second Class
# 62        63  CA-2016-135545  24/11/2016  30/11/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9685    9686  CA-2018-118668  02/01/2018  04/01/2018    Second Class
# 9700    9701  CA-2018-154116  15/12/2018  19/12/2018  Standard Class
# 9725    9726  CA-2018-142293  17/09/2018  20/09/2018     First Class
# 9761    9762  CA-2015-121762  14/02/2015  18/02/2015  Standard Class
# 9764    9765  CA-2015-123855  18/06/2015  23/06/2015  Standard Class
#
#      Customer ID        Customer Name    Segment        Country  \
# 7       BH-11710      Brosina Hoffman   Consumer  United States
# ...

# %%
df[["Customer Name", "Sales","State"]]
# Out:
#          Customer Name     Sales       State
# 0          Claire Gute  261.9600    Kentucky
# 1          Claire Gute  731.9400    Kentucky
# 2      Darrin Van Huff   14.6200  California
# 3       Sean O'Donnell  957.5775     Florida
# 4       Sean O'Donnell   22.3680     Florida
# ...                ...       ...         ...
# 9795     Sally Hughsby    3.7980    Illinois
# 9796  Cindy Schnelling   10.3680        Ohio
# 9797  Cindy Schnelling  235.1880        Ohio
# 9798  Cindy Schnelling   26.3760        Ohio
# 9799  Cindy Schnelling   10.3840        Ohio
#
# [9800 rows x 3 columns]

# %%
df[df["Region"] == "East"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 23        24  US-2018-156909  16/07/2018  18/07/2018    Second Class
# 27        28  US-2016-150630  17/09/2016  21/09/2016  Standard Class
# 28        29  US-2016-150630  17/09/2016  21/09/2016  Standard Class
# 29        30  US-2016-150630  17/09/2016  21/09/2016  Standard Class
# 30        31  US-2016-150630  17/09/2016  21/09/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9784    9785  CA-2016-149748  31/05/2016  02/06/2016    Second Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID      Customer Name    Segment        Country          City  \
# ...

# %%
df[df["Category"] == "Office Supplies"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 6          7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 8          9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 9         10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9791    9792  CA-2015-127166  21/05/2015  23/05/2015    Second Class
# 9793    9794  CA-2015-127166  21/05/2015  23/05/2015    Second Class
# 9794    9795  CA-2015-127166  21/05/2015  23/05/2015    Second Class
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df[(df["Category"] == "Technology") & (df["Region"] == "West")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 19        20  CA-2015-143336  27/08/2015  01/09/2015    Second Class
# 26        27  CA-2017-121755  16/01/2017  20/01/2017    Second Class
# 62        63  CA-2016-135545  24/11/2016  30/11/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9685    9686  CA-2018-118668  02/01/2018  04/01/2018    Second Class
# 9700    9701  CA-2018-154116  15/12/2018  19/12/2018  Standard Class
# 9725    9726  CA-2018-142293  17/09/2018  20/09/2018     First Class
# 9761    9762  CA-2015-121762  14/02/2015  18/02/2015  Standard Class
# 9764    9765  CA-2015-123855  18/06/2015  23/06/2015  Standard Class
#
#      Customer ID        Customer Name    Segment        Country  \
# 7       BH-11710      Brosina Hoffman   Consumer  United States
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Region
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: count, dtype: int64

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: count, dtype: int64

# %%
df.groupby(["Category", "Region"])["Sales"].sum()
# Out:
# Category         Region
# Furniture        Central    160317.4622
#                  East       206461.3880
#                  South      116531.4800
#                  West       245348.2455
# Office Supplies  Central    163590.2430
#                  East       199940.8110
#                  South      124424.7710
#                  West       217466.5090
# Technology       Central    168739.2080
#                  East       263116.5270
#                  South      148195.2080
#                  West       247404.9300
# Name: Sales, dtype: float64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df["Customer ID"].nunique()
# Out:
# 793

# %%
total_sales = df["Sales"].sum()
total_orders = df["Order ID"].nunique()
total_customers = df["Customer ID"].nunique()
average_order_value = total_sales / total_orders
average_order_spending = total_sales / total_customers

print(f"Total Sales: ${total_sales:,}")
print(f"Total Orders: {total_orders:,}")
print(f"Total Customers: {total_customers:,}")
# Out:
# Total Sales: $2,261,536.7827000003
# Total Orders: 4,922
# Total Customers: 793

# %%
df["Category"]
# Out:
# 0             Furniture
# 1             Furniture
# 2       Office Supplies
# 3             Furniture
# 4       Office Supplies
#              ...
# 9795    Office Supplies
# 9796    Office Supplies
# 9797         Technology
# 9798         Technology
# 9799         Technology
# Name: Category, Length: 9800, dtype: object

# %%
df["Sub-Category"]
# Out:
# 0         Bookcases
# 1            Chairs
# 2            Labels
# 3            Tables
# 4           Storage
#            ...
# 9795        Binders
# 9796            Art
# 9797         Phones
# 9798         Phones
# 9799    Accessories
# Name: Sub-Category, Length: 9800, dtype: object

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64
