# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivamb/netflix-shows")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'netflix-shows' dataset.
# Path to dataset files: /kaggle/input/netflix-shows

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.sample(5)
# Out:
#      show_id     type                                title  \
# 7344   s7345    Movie  Love Dot Com: The Social Experiment
# 6179   s6180    Movie      APEX: The Story of the Hypercar
# 2251   s2252  TV Show                           The Twelve
# 7218   s7219    Movie                          Knock Knock
# 5446   s5447    Movie                          Lucid Dream
#
#                       director  \
# 7344             Charneice Fox
# 6179  J.F. Musial, Josh Vietze
# 2251            Wouter Bouvijn
# 7218                  Eli Roth
# 5446             Jun-seong Kim
#
#                                                    cast  \
# 7344  Brave Williams, Tobias Truvillion, Kym Whitley...
# 6179                                       Zachary Levi
# 2251  Maaike Neuville, Charlotte De Bruyne, Tom Verm...
# 7218  Keanu Reeves, Lorenza Izzo, Ana de Armas, Aaro...
# 5446  Ko Soo, Kyung-gu Seol, Yu-chun Park, Hye-jung ...
#
# ...

# %%
df["title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df[["title","type","country"]]
# Out:
#                       title     type        country
# 0      Dick Johnson Is Dead    Movie  United States
# 1             Blood & Water  TV Show   South Africa
# 2                 Ganglands  TV Show            NaN
# 3     Jailbirds New Orleans  TV Show            NaN
# 4              Kota Factory  TV Show          India
# ...                     ...      ...            ...
# 8802                 Zodiac    Movie  United States
# 8803            Zombie Dumb  TV Show            NaN
# 8804             Zombieland    Movie  United States
# 8805                   Zoom    Movie  United States
# 8806                 Zubaan    Movie          India
#
# [8807 rows x 3 columns]

# %%
df[df["type"] == "Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df[df["country"] == "India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
df[df["country"].fillna("").str.contains("India")]
# Out:
#      show_id     type                title                 director  \
# 4         s5  TV Show         Kota Factory                      NaN
# 24       s25    Movie                Jeans               S. Shankar
# 29       s30    Movie             Paranoia           Robert Luketic
# 39       s40  TV Show         Chhota Bheem                      NaN
# 50       s51  TV Show        Dharmakshetra                      NaN
# ...      ...      ...                  ...                      ...
# 8773   s8774    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show      Yeh Meri Family                      NaN
# 8798   s8799    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                Zenda           Avadhoot Gupte
# 8806   s8807    Movie               Zubaan              Mozez Singh
#
#                                                    cast  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...

# %%
df["country"].fillna("").str.contains("india", case=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806     True
# Name: country, Length: 8807, dtype: bool

# %%
df[df["release_year"] > 2020]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda              NaN
# 1696   s1697  TV Show               Polly Pocket              NaN
# 2920   s2921  TV Show              Love Is Blind              NaN
# 8437   s8438  TV Show     The Netflix Afterparty              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[(df["country"] == "India") & (df["type"] == "TV Show")]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
df["country"].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
df["rating"].value_counts().head(10)
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
type_count = df["type"].value_counts()
type_count
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
type_count.plot(kind = "bar")
plt.title("Movies vs TV Shows on Netflix")
plt.xlabel("Content Type")
plt.ylabel("Number of Title")
plt.show()

# %%
rating_count = df["rating"].value_counts().head(10)
rating_count
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: count, dtype: int64

# %%
rating_count.plot(kind="bar")

plt.title("Top 10 Ratings on Netflix")
plt.xlabel("Rating")
plt.ylabel("Number of Title")
plt.show()

# %%
year_count = df["release_year"].value_counts().sort_index()
year_count = year_count.tail(20)

# %%
year_count.plot(kind="line")

plt.title("Netflix Content Release Trend By Year")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.show()

# %%
df["country"] = df["country"].fillna("Unknown")

# %%
country_count = df["country"].value_counts().head(10)
country_count
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
country_count .plot(kind="barh")

plt.title("Top 10 countries by Netflix Content")
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.show()

# %%
india_df = df[df["country"].fillna("").str.contains("india", case=False)]
india_df.head()
# Out:
#    show_id     type          title        director  \
# 4       s5  TV Show   Kota Factory             NaN
# 24     s25    Movie          Jeans      S. Shankar
# 29     s30    Movie       Paranoia  Robert Luketic
# 39     s40  TV Show   Chhota Bheem             NaN
# 50     s51  TV Show  Dharmakshetra             NaN
#
#                                                  cast  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 29  Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 50  Kashmira Irani, Chandan Anand, Dinesh Mehta, A...
#
#                          country          date_added  release_year rating  \
# 4                          India  September 24, 2021          2021  TV-MA
# 24                         India  September 21, 2021          1998  TV-14
# 29  United States, India, France  September 19, 2021          2013  PG-13
# ...

# %%
india_type_count = india_df["type"].value_counts()
india_type_count
# Out:
# type
# Movie      962
# TV Show     84
# Name: count, dtype: int64

# %%
india_type_count.plot(kind="bar")

plt.title("Indian COntent: Movies vs TV Shows")
plt.xlabel("Content Type")
plt.ylabel("Number of Titles")
plt.show()
