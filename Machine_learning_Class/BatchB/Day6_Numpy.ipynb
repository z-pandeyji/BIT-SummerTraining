# %%
import numpy as np

# %%
marks = [60,70,80,90]
print(marks)
# Out:
# [60, 70, 80, 90]

# %%
marks_np = np.array([60,70,80,90])
print(marks_np)
# Out:
# [60 70 80 90]

# %%
marks = [60,70,80,90]

new_marks = []

for mark in marks:
  new_marks.append(mark + 5)

print(new_marks)
# Out:
# [65, 75, 85, 95]

# %%
marks_np = np.array([60,70,80,90])
print(marks_np + 5)
# Out:
# [65 75 85 95]
