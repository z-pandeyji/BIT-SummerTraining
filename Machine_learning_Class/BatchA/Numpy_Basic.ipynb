# %%
import numpy as np

# %%
marks = [60,70,80,90]
print(marks)
# Out:
# [60, 70, 80, 90]

# %%
marks_np = np.array([60,70,80,90])
print(marks_np)
# Out:
# [60 70 80 90]

# %%
marks = [60,70,80,90]

new_marks = []

for mark in marks:
  new_marks.append(mark+5)

print(new_marks)
# Out:
# [65, 75, 85, 95]

# %%
marks_np = np.array([60,70,80,90])

print(marks_np + 5)
# Out:
# [65 75 85 95]

# %%
arr1 = np.array([10,20,30,40])
print(arr1)
# Out:
# [10 20 30 40]

# %%
arr2 = np.array([
    [10,20,30],
    [40,50,60]
])

print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
data = np.array([
    [2,60,45],
    [5,80,70],
    [8, 90, 85],
    [1, 40, 30]
])

print("Shape:", data.shape)
print("Size:", data.size)
print("Dimension:", data.ndim)
print("Data Type:", data.dtype)
# Out:
# Shape: (4, 3)
# Size: 12
# Dimension: 2
# Data Type: int64

# %%
marks = np.array([45, 67, 89, 32, 76])

print(marks[0])
print(marks[-1])
print(marks[1:4])
# Out:
# 45
# 76
# [67 89 32]

# %%
marks = np.array([45,67,89,32,76,90])

print(np.mean(marks))
print(marks.max())
print(np.max(marks))

# max(), sum(), min(), median(), std()
# Out:
# 66.5
# 90
# 90

# %%
arr = np.array([10, 20, "30"])

print(arr)
print(arr.dtype)

# print(arr + 5)
# Out:
# ['10' '20' '30']
# <U21

# %%
arr = np.array([10, 20, np.nan, 40])
print(np.mean(arr))
print(np.sum(arr))
# Out:
# nan
# nan

# %%
arr = np.array([])

# %%
a = np.array([10, 20, 30])
b = np.array([1, 2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2769/3995421940.py in <cell line: 0>()
#       2 b = np.array([1, 2])
#       3
# ----> 4 print( a + b)
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)
